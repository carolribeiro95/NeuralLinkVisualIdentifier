# %% [markdown]
# <a href="https://colab.research.google.com/github/carolribeiro95/NeuralLinkVisualIdentifier/blob/feature%2Fdataset/CNNDogs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aquisição das imagens

# %%
# %pip install bing-image-downloader

# %%
from bing_image_downloader import downloader
downloader.download("dog training", limit=100, output_dir='dataset')
# Out:
# [%] Downloading Images to /content/dataset/dog training
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 47 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://edwize.org/wp-content/uploads/2022/11/6-Best-Masterclass-Dog-Training-Courses-You-Can-Try-Today.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://bookyourpet.com/wp-content/uploads/2024/02/2-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.hartz.com/wp-content/uploads/2021/10/Dog-Training-Basics-2.jpg
# [!] Issue getting: https://www.hartz.com/wp-content/uploads/2021/10/Dog-Training-Basics-2.jpg
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #3 from https://canine-paradise.com/wp-content/uploads/2017/05/puppy-training.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://petsvida.com/wp-content/uploads/2023/09/Early-dog-training-1024x585.jpg
# [%] File Downloaded !
#
# ...

# %%
# Excluir arquivos terminados em ".webp"
# !find dataset -name "*.webp" -type f -delete

# %%
# Importando bibliotecas

import pathlib
import PIL
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
url = '/content/dataset/dog training'

# %%
data_dir = pathlib.Path(url)

# %%
# Contagem total de imagens no dataset
print(f'Total de imagens = {len(list(data_dir.glob('*.jpg')))}')
# Out:
# Total de imagens = 85

# %%
# visualização de imagens
PIL.Image.open(list(data_dir.glob('*.jpg'))[0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1500x1159>

# %%
# Percorre todas as imagens e verifica a dimensão
for i in range(len(list(data_dir.glob('*.jpg')))):
  img = PIL.Image.open(list(data_dir.glob('*.jpg'))[i])
  img_array = np.array(img)
  print(f'Dimensão da imagem {i} = {img_array.shape}')
# Out:
# Dimensão da imagem 0 = (1159, 1500, 3)
# Dimensão da imagem 1 = (1415, 2119, 3)
# Dimensão da imagem 2 = (1024, 1024, 3)
# Dimensão da imagem 3 = (800, 1200, 3)
# Dimensão da imagem 4 = (970, 951, 3)
# Dimensão da imagem 5 = (600, 800, 3)
# Dimensão da imagem 6 = (793, 1920, 3)
# Dimensão da imagem 7 = (800, 1200, 3)
# Dimensão da imagem 8 = (871, 900, 3)
# Dimensão da imagem 9 = (1800, 1200, 3)
# Dimensão da imagem 10 = (768, 1344, 3)
# Dimensão da imagem 11 = (370, 555, 3)
# Dimensão da imagem 12 = (459, 696, 3)
# Dimensão da imagem 13 = (766, 1000, 3)
# Dimensão da imagem 14 = (854, 1280, 3)
# Dimensão da imagem 15 = (1000, 791, 3)
# Dimensão da imagem 16 = (585, 1024, 3)
# Dimensão da imagem 17 = (1018, 720, 3)
# Dimensão da imagem 18 = (721, 1280, 3)
# Dimensão da imagem 19 = (1600, 1213, 3)
# Dimensão da imagem 20 = (486, 729, 3)
# Dimensão da imagem 21 = (720, 1280, 3)
# Dimensão da imagem 22 = (1269, 1400, 3)
# Dimensão da imagem 23 = (720, 1280, 3)
# ...
